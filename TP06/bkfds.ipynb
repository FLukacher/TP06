-- %% [markdown]
-- # [Repaso]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Repaso]    Script Date: 6/8/2025 10:22:17 ******/
CREATE DATABASE [Repaso]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Repaso', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER\MSSQL\DATA\Repaso.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Repaso_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER\MSSQL\DATA\Repaso_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [Repaso] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Repaso].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Repaso] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Repaso] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Repaso] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Repaso] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Repaso] SET ARITHABORT OFF 
GO
ALTER DATABASE [Repaso] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Repaso] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Repaso] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Repaso] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Repaso] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Repaso] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Repaso] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Repaso] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Repaso] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Repaso] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Repaso] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Repaso] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Repaso] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Repaso] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Repaso] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Repaso] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Repaso] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Repaso] SET RECOVERY FULL 
GO
ALTER DATABASE [Repaso] SET  MULTI_USER 
GO
ALTER DATABASE [Repaso] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Repaso] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Repaso] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Repaso] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Repaso] SET DELAYED_DURABILITY = DISABLED 
GO
EXEC sys.sp_db_vardecimal_storage_format N'Repaso', N'ON'
GO
ALTER DATABASE [Repaso] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [alumno]

-- %%
USE [Repaso]
GO

-- %%
/****** Object:  User [alumno]    Script Date: 6/8/2025 10:22:17 ******/
CREATE USER [alumno] FOR LOGIN [alumno] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[Taeras]

-- %%
/****** Object:  Table [dbo].[Taeras]    Script Date: 6/8/2025 10:22:17 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Taeras](
	[Id] [nchar](10) NOT NULL,
	[titulo] [nchar](10) NOT NULL,
	[descripcion] [nchar](10) NOT NULL,
	[fecha] [date] NOT NULL,
	[finalizado] [bit] NOT NULL,
	[IdU] [int] NOT NULL,
 CONSTRAINT [PK_Taeras] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 6/8/2025 10:22:17 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[Id] [int] NOT NULL,
	[nombre] [nchar](10) NOT NULL,
	[apellido] [nchar](10) NOT NULL,
	[foto] [image] NOT NULL,
	[username] [nchar](10) NOT NULL,
	[ultLogin] [date] NOT NULL,
	[password] [nchar](10) NOT NULL,
 CONSTRAINT [PK_Usuario] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Taeras_Usuario]

-- %%
ALTER TABLE [dbo].[Taeras]  WITH CHECK ADD  CONSTRAINT [FK_Taeras_Usuario] FOREIGN KEY([IdU])
REFERENCES [dbo].[Usuario] ([Id])
GO
ALTER TABLE [dbo].[Taeras] CHECK CONSTRAINT [FK_Taeras_Usuario]
GO

-- %% [markdown]
-- # [Repaso]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Repaso] SET  READ_WRITE 
GO
